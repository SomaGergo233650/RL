# %%
import wandb
import os
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback, EvalCallback
from env_V3_final_2 import CustomEnv  # Assuming CustomEnv is in this file
from stable_baselines3.common.monitor import Monitor
import tensorboard


# Initialize the project in WandB (login to WandB manually if needed)
wandb.login()  # Use this for logging in manually
wandb.init(project="sb3_custom_env", sync_tensorboard=True)

# Set hyperparameters directly for Jupyter
learning_rate = 0.00005  # Lower learning rate for more stable gradient updates
batch_size = 32  # Larger batch size for better gradient estimates
n_steps = 2048  # Shorter rollout steps for faster updates
n_epochs = 20  # Increase epochs to improve stability per update
ent_coef = 0.02  # Encourage more exploration (default is often 0.0)
gamma = 0.98  # Discount factor remains unchanged
episodes = 2  # Total number of episodes
iterations_per_episode = 20000  # Iterations per episode

# Set up the environment
env = CustomEnv(render=False, max_steps=n_steps)  # Initialize the custom environment

# Set up PPO model with the custom environment, command-line arguments, and TensorBoard logging
model = PPO(
    'MlpPolicy', 
    env, 
    verbose=1,
    learning_rate=learning_rate, 
    batch_size=batch_size, 
    n_steps=n_steps, 
    n_epochs=n_epochs, 
    ent_coef=ent_coef, 
    tensorboard_log=f"./ppo_custom_env_tensorboard/{wandb.run.id}/"
)


# Training loop for a specific number of episodes
for episode in range(1, episodes + 1):
    print(f"Starting episode {episode}/{episodes}")

    # Total steps per episode = iterations * steps per iteration
    total_timesteps = iterations_per_episode * n_steps  # 200,000 iterations * 1,000 steps/iteration

    # Train the model for the calculated number of timesteps
    model.learn(total_timesteps=total_timesteps, reset_num_timesteps=False, tb_log_name=f"PPO_run_{wandb.run.id}_episode_{episode}")

    # Save the model incrementally after each episode
    model.save(f"ppo_model_episode_{episode}")
    
    # Log the model checkpoint to WandB
    wandb.save(f"ppo_model_episode_{episode}.zip")

# Finish WandB logging after training is complete
wandb.finish()
# Out:
# 2025-01-18 14:16:07.433036: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1737206167.453140  295385 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1737206167.459393  295385 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-18 14:16:07.507815: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# pybullet build time: Sep  3 2024 12:51:03
# wandb: Currently logged in as: 222855 (222855-breda-university-of-applied-sciences). Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.2
# Run data is saved locally in <code>/home/balage/School/2024-25b-fai2-adsai-BalazsCsutar222855/rl_PUB/Task_9/wandb/run-20250118_141611-74cddbb0</code>
# Syncing run <strong><a href='https://wandb.ai/222855-breda-university-of-applied-sciences/sb3_custom_env/runs/74cddbb0' target="_blank">hardy-leaf-166</a></strong> to <a href='https://wandb.ai/222855-breda-university-of-applied-sciences/sb3_custom_env' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/222855-breda-university-of-applied-sciences/sb3_custom_env' target="_blank">https://wandb.ai/222855-breda-university-of-applied-sciences/sb3_custom_env</a>
#  View run at <a href='https://wandb.ai/222855-breda-university-of-applied-sciences/sb3_custom_env/runs/74cddbb0' target="_blank">https://wandb.ai/222855-breda-university-of-applied-sciences/sb3_custom_env/runs/74cddbb0</a>
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Starting episode 1/2
# Logging to ./ppo_custom_env_tensorboard/74cddbb0/PPO_run_74cddbb0_episode_1_0
# /home/balage/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 2.05e+03  |
# |    ep_rew_mean     | -1.87e+03 |
# | time/              |           |
# |    fps             | 568       |
# |    iterations      | 1         |
# |    time_elapsed    | 3         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.05e+03     |
# |    ep_rew_mean          | -1.83e+03    |
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0040955488 |
# |    clip_fraction        | 0.00544      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.00698      |
# |    learning_rate        | 5e-05        |
# |    loss                 | 23.4         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00111     |
# |    std                  | 0.997        |
# |    value_loss           | 134          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.56e+03     |
# |    ep_rew_mean          | -1.25e+03    |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0052016773 |
# |    clip_fraction        | 0.0264       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | -0.024       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 25.4         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00288     |
# |    std                  | 0.998        |
# |    value_loss           | 102          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.68e+03     |
# |    ep_rew_mean          | -1.4e+03     |
# | time/                   |              |
# |    fps                  | 304          |
# |    iterations           | 4            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0049773054 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | 0.277        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 25           |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00128     |
# |    std                  | 1.01         |
# |    value_loss           | 75.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.75e+03    |
# |    ep_rew_mean          | -1.59e+03   |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 5           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005240704 |
# |    clip_fraction        | 0.0284      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | 0.0437      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 65.8        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00437    |
# |    std                  | 1.01        |
# |    value_loss           | 168         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.8e+03      |
# |    ep_rew_mean          | -1.54e+03    |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 6            |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0039215167 |
# |    clip_fraction        | 0.026        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.31        |
# |    explained_variance   | 0.0677       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 14.5         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0034      |
# |    std                  | 1.02         |
# |    value_loss           | 70.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.84e+03     |
# |    ep_rew_mean          | -1.44e+03    |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 7            |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0044989577 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.32        |
# |    explained_variance   | -0.000643    |
# |    learning_rate        | 5e-05        |
# |    loss                 | 1.26         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00249     |
# |    std                  | 1.02         |
# |    value_loss           | 9.63         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.86e+03     |
# |    ep_rew_mean          | -1.45e+03    |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 8            |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0005823019 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.31        |
# |    explained_variance   | 0.00451      |
# |    learning_rate        | 5e-05        |
# |    loss                 | 6.95         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -4.36e-05    |
# |    std                  | 1.02         |
# |    value_loss           | 22.7         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.88e+03      |
# |    ep_rew_mean          | -1.55e+03     |
# | time/                   |               |
# |    fps                  | 294           |
# |    iterations           | 9             |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.00081629754 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.31         |
# |    explained_variance   | 0.000863      |
# |    learning_rate        | 5e-05         |
# |    loss                 | 33.4          |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000765     |
# |    std                  | 1.02          |
# |    value_loss           | 109           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.9e+03      |
# |    ep_rew_mean          | -1.44e+03    |
# | time/                   |              |
# |    fps                  | 294          |
# |    iterations           | 10           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0011857074 |
# |    clip_fraction        | 0.0012       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.32        |
# |    explained_variance   | 0.0224       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 11.2         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000599    |
# |    std                  | 1.03         |
# |    value_loss           | 41.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.91e+03     |
# |    ep_rew_mean          | -1.52e+03    |
# | time/                   |              |
# |    fps                  | 295          |
# |    iterations           | 11           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0024700426 |
# |    clip_fraction        | 0.00061      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.33        |
# |    explained_variance   | 0.484        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 19.6         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00111     |
# |    std                  | 1.03         |
# |    value_loss           | 66.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.92e+03     |
# |    ep_rew_mean          | -1.54e+03    |
# | time/                   |              |
# |    fps                  | 295          |
# |    iterations           | 12           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0028968574 |
# |    clip_fraction        | 0.00632      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.34        |
# |    explained_variance   | 0.0317       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 8.58         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00167     |
# |    std                  | 1.03         |
# |    value_loss           | 40.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.93e+03     |
# |    ep_rew_mean          | -1.5e+03     |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 13           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0028803363 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.36        |
# |    explained_variance   | 0.0279       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 1.93         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00163     |
# |    std                  | 1.04         |
# |    value_loss           | 15.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94e+03    |
# |    ep_rew_mean          | -1.44e+03   |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 14          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006638162 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.38       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 23.9        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00344    |
# |    std                  | 1.05        |
# |    value_loss           | 12.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.95e+03     |
# |    ep_rew_mean          | -1.46e+03    |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 15           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0049157636 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 1.09         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00255     |
# |    std                  | 1.05         |
# |    value_loss           | 6.4          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.96e+03     |
# |    ep_rew_mean          | -1.47e+03    |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 16           |
# |    time_elapsed         | 110          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0060479688 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.4         |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 13           |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00168     |
# |    std                  | 1.05         |
# |    value_loss           | 15.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.96e+03    |
# |    ep_rew_mean          | -1.51e+03   |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 17          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005144414 |
# |    clip_fraction        | 0.00811     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.39       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 1.89        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00162    |
# |    std                  | 1.05        |
# |    value_loss           | 24.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.97e+03     |
# |    ep_rew_mean          | -1.45e+03    |
# | time/                   |              |
# |    fps                  | 297          |
# |    iterations           | 18           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0028977985 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0.935        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 32.1         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00164     |
# |    std                  | 1.05         |
# |    value_loss           | 22.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.97e+03     |
# |    ep_rew_mean          | -1.48e+03    |
# | time/                   |              |
# |    fps                  | 297          |
# |    iterations           | 19           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0052555157 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.747        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00226     |
# |    std                  | 1.05         |
# |    value_loss           | 10.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.97e+03    |
# |    ep_rew_mean          | -1.44e+03   |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 20          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006802305 |
# |    clip_fraction        | 0.0624      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.4        |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 1.9         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00668    |
# |    std                  | 1.05        |
# |    value_loss           | 21.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.98e+03     |
# |    ep_rew_mean          | -1.44e+03    |
# | time/                   |              |
# |    fps                  | 294          |
# |    iterations           | 21           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0061103813 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.4         |
# |    explained_variance   | 0.755        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0182      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00148     |
# |    std                  | 1.05         |
# |    value_loss           | 3.57         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.98e+03     |
# |    ep_rew_mean          | -1.46e+03    |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 22           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0070825964 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.4         |
# |    explained_variance   | 0.97         |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.306        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00448     |
# |    std                  | 1.05         |
# |    value_loss           | 7.72         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.98e+03     |
# |    ep_rew_mean          | -1.45e+03    |
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 23           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0039341385 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.41        |
# |    explained_variance   | 0.0112       |
# |    learning_rate        | 5e-05        |
# |    loss                 | 12.4         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000645    |
# |    std                  | 1.05         |
# |    value_loss           | 23           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | -1.46e+03    |
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 24           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0031529227 |
# |    clip_fraction        | 0.00605      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.42        |
# |    explained_variance   | 0.853        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.162        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0015      |
# |    std                  | 1.06         |
# |    value_loss           | 22.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | -1.47e+03    |
# | time/                   |              |
# |    fps                  | 282          |
# |    iterations           | 25           |
# |    time_elapsed         | 181          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0052909125 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.43        |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.176        |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00569     |
# |    std                  | 1.06         |
# |    value_loss           | 5.4          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.99e+03    |
# |    ep_rew_mean          | -1.46e+03   |
# | time/                   |             |
# |    fps                  | 281         |
# |    iterations           | 26          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006340144 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.44       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 1.24        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0056     |
# |    std                  | 1.06        |
# |    value_loss           | 23          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | -1.48e+03    |
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 27           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0011918476 |
# |    clip_fraction        | 7.32e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.44        |
# |    explained_variance   | 0.858        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0547       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.000311    |
# |    std                  | 1.07         |
# |    value_loss           | 15           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.47e+03    |
# | time/                   |              |
# |    fps                  | 279          |
# |    iterations           | 28           |
# |    time_elapsed         | 205          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0028501377 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.44        |
# |    explained_variance   | 0.183        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.655        |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00192     |
# |    std                  | 1.06         |
# |    value_loss           | 25.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.44e+03    |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 29           |
# |    time_elapsed         | 213          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0054651564 |
# |    clip_fraction        | 0.0372       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.43        |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 2.57         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00315     |
# |    std                  | 1.06         |
# |    value_loss           | 20.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.41e+03   |
# | time/                   |             |
# |    fps                  | 276         |
# |    iterations           | 30          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.007001135 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.43       |
# |    explained_variance   | 0.789       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0334      |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00575    |
# |    std                  | 1.06        |
# |    value_loss           | 1.52        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.41e+03    |
# | time/                   |              |
# |    fps                  | 274          |
# |    iterations           | 31           |
# |    time_elapsed         | 230          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0046456484 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.44        |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.968        |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.0039      |
# |    std                  | 1.07         |
# |    value_loss           | 2.2          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | -1.38e+03   |
# | time/                   |             |
# |    fps                  | 273         |
# |    iterations           | 32          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004021778 |
# |    clip_fraction        | 0.0325      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.45       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.052       |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00297    |
# |    std                  | 1.07        |
# |    value_loss           | 18.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.38e+03    |
# | time/                   |              |
# |    fps                  | 271          |
# |    iterations           | 33           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0060149347 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.46        |
# |    explained_variance   | -0.364       |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0488      |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.00181     |
# |    std                  | 1.07         |
# |    value_loss           | 5.74         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | -1.37e+03    |
# | time/                   |              |
# |    fps                  | 270          |
# |    iterations           | 34           |
# |    time_elapsed         | 257          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0055274228 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.48        |
# |    explained_variance   | 0.869        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0188       |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.00289     |
# |    std                  | 1.08         |
# |    value_loss           | 7.47         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | -1.36e+03    |
# | time/                   |              |
# |    fps                  | 269          |
# |    iterations           | 35           |
# |    time_elapsed         | 265          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0051240036 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.48        |
# |    explained_variance   | -0.0431      |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.801        |
# |    n_updates            | 680          |
# |    policy_gradient_loss | -0.00146     |
# |    std                  | 1.08         |
# |    value_loss           | 15           |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.01e+03   |
# |    ep_rew_mean          | -1.35e+03  |
# | time/                   |            |
# |    fps                  | 267        |
# |    iterations           | 36         |
# |    time_elapsed         | 275        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.00433605 |
# |    clip_fraction        | 0.0384     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.49      |
# |    explained_variance   | 0.192      |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.0209    |
# |    n_updates            | 700        |
# |    policy_gradient_loss | -0.00149   |
# |    std                  | 1.08       |
# |    value_loss           | 12.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01e+03    |
# |    ep_rew_mean          | -1.36e+03   |
# | time/                   |             |
# |    fps                  | 266         |
# |    iterations           | 37          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.003286547 |
# |    clip_fraction        | 0.0245      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | 0.775       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.00502     |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.00145    |
# |    std                  | 1.09        |
# |    value_loss           | 13.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | -1.34e+03    |
# | time/                   |              |
# |    fps                  | 265          |
# |    iterations           | 38           |
# |    time_elapsed         | 293          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0034960364 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.52        |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 7.37         |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -0.00272     |
# |    std                  | 1.09         |
# |    value_loss           | 21.4         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.01e+03   |
# |    ep_rew_mean          | -1.35e+03  |
# | time/                   |            |
# |    fps                  | 263        |
# |    iterations           | 39         |
# |    time_elapsed         | 302        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.00473924 |
# |    clip_fraction        | 0.034      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.52      |
# |    explained_variance   | -1.14      |
# |    learning_rate        | 5e-05      |
# |    loss                 | 0.027      |
# |    n_updates            | 760        |
# |    policy_gradient_loss | -0.00355   |
# |    std                  | 1.09       |
# |    value_loss           | 8.47       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01e+03    |
# |    ep_rew_mean          | -1.36e+03   |
# | time/                   |             |
# |    fps                  | 263         |
# |    iterations           | 40          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.004287528 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.52       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0151      |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.00193    |
# |    std                  | 1.09        |
# |    value_loss           | 10.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | -1.35e+03    |
# | time/                   |              |
# |    fps                  | 263          |
# |    iterations           | 41           |
# |    time_elapsed         | 319          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0052772923 |
# |    clip_fraction        | 0.0426       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.51        |
# |    explained_variance   | 0.855        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0438       |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.0031      |
# |    std                  | 1.09         |
# |    value_loss           | 21.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01e+03    |
# |    ep_rew_mean          | -1.35e+03   |
# | time/                   |             |
# |    fps                  | 262         |
# |    iterations           | 42          |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008406453 |
# |    clip_fraction        | 0.076       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.5        |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.139       |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00414    |
# |    std                  | 1.08        |
# |    value_loss           | 8.93        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01e+03    |
# |    ep_rew_mean          | -1.37e+03   |
# | time/                   |             |
# |    fps                  | 262         |
# |    iterations           | 43          |
# |    time_elapsed         | 335         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004722072 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.5        |
# |    explained_variance   | 0.828       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.00666     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00293    |
# |    std                  | 1.09        |
# |    value_loss           | 15.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.01e+03   |
# |    ep_rew_mean          | -1.36e+03  |
# | time/                   |            |
# |    fps                  | 261        |
# |    iterations           | 44         |
# |    time_elapsed         | 343        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.00317195 |
# |    clip_fraction        | 0.0237     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.52      |
# |    explained_variance   | 0.768      |
# |    learning_rate        | 5e-05      |
# |    loss                 | 47.9       |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.00285   |
# |    std                  | 1.1        |
# |    value_loss           | 27.3       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.02e+03     |
# |    ep_rew_mean          | -1.35e+03    |
# | time/                   |              |
# |    fps                  | 260          |
# |    iterations           | 45           |
# |    time_elapsed         | 353          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0036748897 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.54        |
# |    explained_variance   | 0.548        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0826       |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00292     |
# |    std                  | 1.1          |
# |    value_loss           | 12.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.02e+03    |
# |    ep_rew_mean          | -1.33e+03   |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 46          |
# |    time_elapsed         | 362         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.005730139 |
# |    clip_fraction        | 0.0731      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.54       |
# |    explained_variance   | 0.171       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0014      |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00295    |
# |    std                  | 1.1         |
# |    value_loss           | 14.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.02e+03    |
# |    ep_rew_mean          | -1.33e+03   |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 47          |
# |    time_elapsed         | 371         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.004290607 |
# |    clip_fraction        | 0.0233      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.55       |
# |    explained_variance   | -0.188      |
# |    learning_rate        | 5e-05       |
# |    loss                 | 6.83        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00204    |
# |    std                  | 1.11        |
# |    value_loss           | 10.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.02e+03    |
# |    ep_rew_mean          | -1.34e+03   |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 48          |
# |    time_elapsed         | 379         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.007820148 |
# |    clip_fraction        | 0.0463      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.55       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 13.8        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00369    |
# |    std                  | 1.1         |
# |    value_loss           | 11.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.02e+03     |
# |    ep_rew_mean          | -1.36e+03    |
# | time/                   |              |
# |    fps                  | 258          |
# |    iterations           | 49           |
# |    time_elapsed         | 388          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0046772026 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.55        |
# ...
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 214          |
# |    iterations           | 296          |
# |    time_elapsed         | 2830         |
# |    total_timesteps      | 606208       |
# | train/                  |              |
# |    approx_kl            | 0.0029395581 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.63        |
# |    explained_variance   | 0.213        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.566        |
# |    n_updates            | 5900         |
# |    policy_gradient_loss | -0.000361    |
# |    std                  | 1.58         |
# |    value_loss           | 14.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 214          |
# |    iterations           | 297          |
# |    time_elapsed         | 2839         |
# |    total_timesteps      | 608256       |
# | train/                  |              |
# |    approx_kl            | 0.0052280044 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.63        |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.00144     |
# |    n_updates            | 5920         |
# |    policy_gradient_loss | -0.000683    |
# |    std                  | 1.58         |
# |    value_loss           | 16.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 214          |
# |    iterations           | 298          |
# |    time_elapsed         | 2850         |
# |    total_timesteps      | 610304       |
# | train/                  |              |
# |    approx_kl            | 0.0051100315 |
# |    clip_fraction        | 0.0387       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.64        |
# |    explained_variance   | 0.222        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.471        |
# |    n_updates            | 5940         |
# |    policy_gradient_loss | -0.00234     |
# |    std                  | 1.59         |
# |    value_loss           | 13.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01e+03    |
# |    ep_rew_mean          | -1.22e+03   |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 299         |
# |    time_elapsed         | 2861        |
# |    total_timesteps      | 612352      |
# | train/                  |             |
# |    approx_kl            | 0.004192262 |
# |    clip_fraction        | 0.0275      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0471     |
# |    n_updates            | 5960        |
# |    policy_gradient_loss | -0.00212    |
# |    std                  | 1.59        |
# |    value_loss           | 11.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 213          |
# |    iterations           | 300          |
# |    time_elapsed         | 2871         |
# |    total_timesteps      | 614400       |
# | train/                  |              |
# |    approx_kl            | 0.0061825914 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.65        |
# |    explained_variance   | 0.839        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 17.8         |
# |    n_updates            | 5980         |
# |    policy_gradient_loss | -0.00242     |
# |    std                  | 1.59         |
# |    value_loss           | 34.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 213          |
# |    iterations           | 301          |
# |    time_elapsed         | 2882         |
# |    total_timesteps      | 616448       |
# | train/                  |              |
# |    approx_kl            | 0.0042173336 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.65        |
# |    explained_variance   | 0.787        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 9.52         |
# |    n_updates            | 6000         |
# |    policy_gradient_loss | -0.00216     |
# |    std                  | 1.59         |
# |    value_loss           | 15           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01e+03    |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 302         |
# |    time_elapsed         | 2892        |
# |    total_timesteps      | 618496      |
# | train/                  |             |
# |    approx_kl            | 0.003231107 |
# |    clip_fraction        | 0.0153      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.65       |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.242       |
# |    n_updates            | 6020        |
# |    policy_gradient_loss | -0.00168    |
# |    std                  | 1.59        |
# |    value_loss           | 7.34        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 213          |
# |    iterations           | 303          |
# |    time_elapsed         | 2903         |
# |    total_timesteps      | 620544       |
# | train/                  |              |
# |    approx_kl            | 0.0045334743 |
# |    clip_fraction        | 0.00691      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.65        |
# |    explained_variance   | 0.439        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.251        |
# |    n_updates            | 6040         |
# |    policy_gradient_loss | 0.000117     |
# |    std                  | 1.59         |
# |    value_loss           | 8.63         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 213          |
# |    iterations           | 304          |
# |    time_elapsed         | 2915         |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0048993807 |
# |    clip_fraction        | 0.0257       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.66        |
# |    explained_variance   | 0.7          |
# |    learning_rate        | 5e-05        |
# |    loss                 | 21.9         |
# |    n_updates            | 6060         |
# |    policy_gradient_loss | -0.00231     |
# |    std                  | 1.6          |
# |    value_loss           | 10           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01e+03    |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 305         |
# |    time_elapsed         | 2927        |
# |    total_timesteps      | 624640      |
# | train/                  |             |
# |    approx_kl            | 0.004014884 |
# |    clip_fraction        | 0.0253      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 3.27        |
# |    n_updates            | 6080        |
# |    policy_gradient_loss | 0.000471    |
# |    std                  | 1.6         |
# |    value_loss           | 16.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 213          |
# |    iterations           | 306          |
# |    time_elapsed         | 2936         |
# |    total_timesteps      | 626688       |
# | train/                  |              |
# |    approx_kl            | 0.0037129456 |
# |    clip_fraction        | 0.00769      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.67        |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.13         |
# |    n_updates            | 6100         |
# |    policy_gradient_loss | -9.88e-05    |
# |    std                  | 1.61         |
# |    value_loss           | 5.77         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.01e+03    |
# |    ep_rew_mean          | -1.21e+03   |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 307         |
# |    time_elapsed         | 2946        |
# |    total_timesteps      | 628736      |
# | train/                  |             |
# |    approx_kl            | 0.002352054 |
# |    clip_fraction        | 0.00496     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 21.1        |
# |    n_updates            | 6120        |
# |    policy_gradient_loss | 0.000183    |
# |    std                  | 1.61        |
# |    value_loss           | 32.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | -1.22e+03    |
# | time/                   |              |
# |    fps                  | 213          |
# |    iterations           | 308          |
# |    time_elapsed         | 2958         |
# |    total_timesteps      | 630784       |
# | train/                  |              |
# |    approx_kl            | 0.0032221596 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.899        |
# |    learning_rate        | 5e-05        |
# |    loss                 | -0.0602      |
# |    n_updates            | 6140         |
# |    policy_gradient_loss | -0.0037      |
# |    std                  | 1.62         |
# |    value_loss           | 8.27         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | -1.21e+03    |
# | time/                   |              |
# |    fps                  | 213          |
# |    iterations           | 309          |
# |    time_elapsed         | 2968         |
# |    total_timesteps      | 632832       |
# | train/                  |              |
# |    approx_kl            | 0.0038320518 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.69        |
# |    explained_variance   | 0.646        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.111        |
# |    n_updates            | 6160         |
# |    policy_gradient_loss | -0.00241     |
# |    std                  | 1.61         |
# |    value_loss           | 16.5         |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 49
#      46 total_timesteps = iterations_per_episode * n_steps  # 200,000 iterations * 1,000 steps/iteration
#      48 # Train the model for the calculated number of timesteps
# ---> 49 model.learn(total_timesteps=total_timesteps, reset_num_timesteps=False, tb_log_name=f"PPO_run_{wandb.run.id}_episode_{episode}")
#      51 # Save the model incrementally after each episode
#      52 model.save(f"ppo_model_episode_{episode}")
#
# File ~/anaconda3/lib/python3.12/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:323, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     320 assert self.env is not None
#     322 while self.num_timesteps < total_timesteps:
# --> 323     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     325     if not continue_training:
#     326         break
#
# File ~/anaconda3/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:199, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     195 if self.use_sde and self.sde_sample_freq > 0 and n_steps % self.sde_sample_freq == 0:
#     196     # Sample a new noise matrix
#     197     self.policy.reset_noise(env.num_envs)
# --> 199 with th.no_grad():
#     200     # Convert to pytorch tensor or to TensorDict
#     201     obs_tensor = obs_as_tensor(self._last_obs, self.device)
#     202     actions, values, log_probs = self.policy(obs_tensor)
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/autograd/grad_mode.py:85, in no_grad.__exit__(self, exc_type, exc_value, traceback)
#      84 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
# ---> 85     torch.set_grad_enabled(self.prev)
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/autograd/grad_mode.py:185, in set_grad_enabled.__init__(self, mode)
#     184 def __init__(self, mode: bool) -> None:
# --> 185     self.prev = torch.is_grad_enabled()
#     186     self.mode = mode
#     187     torch._C._set_grad_enabled(mode)
#
# KeyboardInterrupt:
